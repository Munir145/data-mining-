# %%
# !pip install pandas

# %% [markdown]
# untuk menginstal library 'pandas'

# %%
import pandas as pd

# %% [markdown]
# untuk impor 'pandas' ke pd

# %%
from google.colab import drive

# %% [markdown]
# untuk impor data dari drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# untuk mengonekkan dengan drive

# %%
path = '/content/drive/MyDrive/bmw_global_sales_dataset.csv'

# %% [markdown]
# untuk uploud file dan menyimpannya

# %%
df = pd.read_csv(path)

# %% [markdown]
# ngolah

# %%
df.head(5)
# Out:
#    year  month    country     model   segment engine_type  price_usd  \
# 0  2021      1  Australia        X1       SUV      Petrol      82234
# 1  2018      8  Australia        i4     Sedan    Electric      82291
# 2  2022     12        USA  5 Series  Electric      Hybrid      40594
# 3  2019     11  Australia        i7       SUV    Electric      42371
# 4  2021     12     Brazil        X5       SUV      Diesel      82315
#
#    marketing_spend_usd  dealership_count  fuel_price_usd  gdp_growth_percent  \
# 0               315372                96            0.97                6.29
# 1               447798               234            0.97                6.29
# 2               259755                25            0.97                6.29
# 3               323541               319            0.97                6.29
# 4               482015               367            0.97                6.29
#
#    interest_rate_percent  competition_index  units_sold
# ...

# %% [markdown]
# menampilkan 5 awal

# %%
df.tail(5)
# Out:
#      year  month country     model segment engine_type  price_usd  \
# 995  2024     10      UK        i4   Sedan    Electric      64813
# 996  2024      2   India  3 Series   Sedan      Petrol     119431
# 997  2022      2  Brazil  5 Series     SUV    Electric     100679
# 998  2016      1  Brazil        i7   Sedan      Hybrid      45681
# 999  2023     10   China  7 Series   Sedan      Petrol     107903
#
#      marketing_spend_usd  dealership_count  fuel_price_usd  \
# 995               126425               177            0.97
# 996               473502                56            0.97
# 997                65994               212            0.97
# 998               161915               223            0.97
# 999               435105               255            0.97
#
#      gdp_growth_percent  interest_rate_percent  competition_index  units_sold
# 995                6.29                    1.2                  1         570
# ...

# %% [markdown]
# 5 terakhir

# %%
df.loc[3]
# Out:
# year                          2019
# month                           11
# country                  Australia
# model                           i7
# segment                        SUV
# engine_type               Electric
# price_usd                    42371
# marketing_spend_usd         323541
# dealership_count               319
# fuel_price_usd                0.97
# gdp_growth_percent            6.29
# interest_rate_percent          1.2
# competition_index                5
# units_sold                     730
# Name: 3, dtype: object

# %% [markdown]
# menampilkan data dengan nomor urut 3

# %%
df.iloc[1:20]
# Out:
#     year  month    country     model   segment engine_type  price_usd  \
# 1   2018      8  Australia        i4     Sedan    Electric      82291
# 2   2022     12        USA  5 Series  Electric      Hybrid      40594
# 3   2019     11  Australia        i7       SUV    Electric      42371
# 4   2021     12     Brazil        X5       SUV      Diesel      82315
# 5   2024     12      China        i7  Electric      Diesel     118564
# 6   2017      4        USA        i4  Electric      Diesel     114526
# 7   2021      4        USA        X7     Sedan      Diesel      51626
# 8   2022      5      India  3 Series     Sedan      Petrol      42130
# 9   2019      8         UK  7 Series       SUV      Petrol      41828
# 10  2018      5         UK  5 Series  Electric    Electric      92514
# 11  2022      8     Brazil        X3  Electric      Hybrid      87664
# 12  2022     10     Canada        X3  Electric      Diesel      52883
# ...

# %% [markdown]
# menampilkan data sesuai interval dengan batas tentu

# %%
df['country'] [1:10]
# Out:
# 1    Australia
# 2          USA
# 3    Australia
# 4       Brazil
# 5        China
# 6          USA
# 7          USA
# 8        India
# 9           UK
# Name: country, dtype: object

# %% [markdown]
# menampilkan data sesuai label yan diminta dengan interval tentu
